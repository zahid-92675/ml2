# %% [markdown]
# Linear Regression

# %%
import numpy as np
import matplotlib.pyplot as plt   # used to vaiualize the data
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataSet = pd.read_csv('/content/drive/MyDrive/483/50_Startups_multi.csv')
dataSet.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
x =
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]

# %%
Y = dataset.iloc[:,-1].values   ## Printing the Salaries
print(Y)
# Out:
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %%
from sklearn.model_selection import train_test_split   ## Training the Model
x_train, x_test, y_train, y_test = train_test_split (X,Y,test_size=1/3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression  #training the model
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict (x_test)   #predicting the result

# %% [markdown]
# Regression Line and the Scatter Plot.
# It shows a postive Slope with no outliners.
#   ""Graph""

# %%
plt.scatter (x_train, y_train,color = 'black')
plt.plot (x_train, regressor.predict (x_train))
plt.title ("Salary VS Experience")
plt.xlabel ("Experience (Years)")
plt.ylabel ("Salary")
plt.show()
